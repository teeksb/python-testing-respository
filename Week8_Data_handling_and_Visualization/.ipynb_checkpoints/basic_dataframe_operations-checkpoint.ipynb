# %%
import pandas as pd

# %%
students_df = pd.read_csv("files/students_record.csv")

print("DataFrame shape (rows, columns):", students_df.shape)
print("\nColumn names(in the form of a list):", students_df.columns.tolist())
print("\nData types:")
print(students_df.dtypes)


print(students_df.describe()) #gives a
# Out:
# DataFrame shape (rows, columns): (20, 11)
#
# Column names(in the form of a list): ['student_id', 'first_name', 'last_name', 'gender', 'age', 'grade_level', 'math_score', 'science_score', 'english_score', 'history_score', 'attendance_rate']
#
# Data types:
# student_id             str
# first_name             str
# last_name              str
# gender                 str
# age                  int64
# grade_level          int64
# math_score           int64
# science_score        int64
# english_score        int64
# history_score        int64
# attendance_rate    float64
# dtype: object
#              age  grade_level  math_score  science_score  english_score  \
# count  20.000000    20.000000    20.00000      20.000000      20.000000
# mean   16.000000    10.100000    80.60000      80.700000      81.600000
# std     0.794719     0.718185    12.17158       9.079184       9.848323
# min    15.000000     9.000000    45.00000      58.000000      65.000000
# 25%    15.000000    10.000000    75.25000      75.500000      74.250000
# 50%    16.000000    10.000000    83.00000      81.500000      84.500000
# 75%    17.000000    11.000000    89.50000      87.250000      88.500000
# max    17.000000    11.000000    95.00000      96.000000      95.000000
#
#        history_score  attendance_rate
# count      20.000000        20.000000
# mean       81.550000         0.901500
# std         9.450564         0.061497
# min        63.000000         0.750000
# 25%        77.500000         0.875000
# 50%        81.500000         0.915000
# 75%        88.750000         0.942500
# max        94.000000         0.980000
