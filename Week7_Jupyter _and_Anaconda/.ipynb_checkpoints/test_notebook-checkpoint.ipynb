# %%
print("Hello World")
# Out:
# Hello World

# %%
def multiply (a, b, c):
    return a * b * c

# %%
result = multiply(8, 3, 2)
print(result)
# Out:
# 48

# %%
location = input("Please enter your location: ")
print(f"The user currently stays in {location}")
# Out:
# Please enter your location:  Canada
# The user currently stays in Canada

# %% [markdown]
# Test Heading 1
#
# Listen to your sister, Morty. To live is to risk it all, otherwise you’re just an inert chunk of randomly assembled molecules drifting wherever the universe blows you.
