# %% [markdown]
# ## Scenario
# You're a junior data analyst at a retail company. The sales team has provided you with a CSV file containing transaction records for the past year. Your manager needs insights to make strategic decisions about inventory, regional focus, and product mix.

# %%
import csv
from pprint import pprint

# %%
STORE_DATA_FILE = "Files/sample_superstore.csv"

# %% [markdown]
# ### Part 1 : Data Loading & Exploration

# %%
def load_sales_data(filename):
    """Load and clean sales data from CSV file"""
    
    sales_data = []
    
    try:
        with open(filename, "r") as file:
            reader = csv.DictReader(file)
            
            for row in reader:
                try:
                    # Convert numeric fields
                    sales = float(row['Sales'])
                    quantity = int(row['Quantity'])
                    discount = float(row['Discount'])
                    profit = float(row['Profit'])
                    
                    # Fix discount if entered as 20 instead of 0.20
                    if discount > 1:
                        discount = discount / 100
                    
                    if sales < 0:
                        continue   # skip negative sales
                    
                    if quantity <= 0:
                        continue   # skip zero or negative quantity
                    
                    if discount < 0 or discount > 1:
                        continue   # skip invalid discount
                    
                    # Save cleaned values back into row
                    row['Sales'] = sales
                    row['Quantity'] = quantity
                    row['Discount'] = discount
                    row['Profit'] = profit
                    
                    sales_data.append(row)
                
                except ValueError:
                    # Skip rows with invalid numbers
                    continue
        
        return sales_data
    
    except FileNotFoundError:
        print(f"Error: {filename} not found")
        return []
    
    except Exception as e:
        print(f"Error loading data: {e}")
        return []
    
data = load_sales_data(STORE_DATA_FILE)
pprint(f"Rows loaded: {len(data)}")
print("************************")
pprint(data[:5])

# %%
def explore_data(sales_data):
    """Display dataset exploration statistics"""
    # Total number of orders (rows)
    total_orders = len(sales_data)
    
    # Date range
    order_dates = []
    for row in sales_data:
        order_dates.append(row["Order Date"])
    
    earliest_date = min(order_dates)
    latest_date = max(order_dates)
    
    # Unique Regions
    regions = set()
    for row in sales_data:
        regions.add(row["Region"])
    
    # Unique Categories
    categories = set()
    for row in sales_data:
        categories.add(row["Category"])
    
    # Unique products
    products = set()
    for row in sales_data:
        products.add(row["Product Name"])
    
  
    # Display results
    print("DATASET EXPLORATION")
    print("-----------------")
    print("Total Orders:", total_orders)
    print("Date Range:", earliest_date, "to", latest_date)
    print("Unique Regions:", list(regions))
    print("Unique Categories:", list(categories))
    print("Number of Unique Products:", len(products))

explore_data(data)

# %% [markdown]
# ### Part 2: Sales Perfomance Analysis

# %%
def calculate_revenue_metrics(sales_data):
    """Calculate overall revenue metrics"""
    if not sales_data:
        return {
            "Total Revenue": 0,
            "Total Profit": 0,
            "Total Quantity Sold": 0,
            "Average Order Value": 0,
            "Profit Margin (%)": 0
        }

    total_revenue = 0
    total_profit = 0
    total_quantity = 0

    for row in sales_data:
        total_revenue += row["Sales"]
        total_profit += row["Profit"]
        total_quantity += row["Quantity"]

    number_orders = len(sales_data)
    avg_order_value = total_revenue / number_orders

    if total_revenue != 0:
        profit_margin = (total_profit / total_revenue) * 100
    else:
        profit_margin = 0

    return {
        "Total Revenue": total_revenue,
        "Total Profit": total_profit,
        "Total Quantity Sold": total_quantity,
        "Average Order Value": avg_order_value,
        "Profit Margin (%)": profit_margin
    }

# %%
def analyze_by_region(sales_data):
    """Analyze sales performance by region"""
    if not sales_data:
        return {}

    region_data = {}

    # sum totals
    for row in sales_data:
        region = row["Region"]
        sales = row["Sales"]
        profit = row["Profit"]

        if region not in region_data:
            region_data[region] = {
                "total_sales": 0,
                "total_profit": 0,
                "order_count": 0
            }

        region_data[region]["total_sales"] += sales  #region_data[region]["total_sales"] = region_data[region]["total_sales"] + row["Sales"]
        region_data[region]["total_profit"] += profit
        region_data[region]["order_count"] += 1

    # Calculate average order value
    for region in region_data:
        total_sales = region_data[region]["total_sales"]
        order_count = region_data[region]["order_count"]

        if order_count > 0:
            region_data[region]["avg_order_value"] = total_sales / order_count
        else:
            region_data[region]["avg_order_value"] = 0

    return region_data

# %%
def analyze_by_category(sales_data):
    """Analyze sales performance by category"""
    if not sales_data:
        return {}

    category_data = {}

    # Sum the totals
    for row in sales_data:
        category = row["Category"]
        sales = row["Sales"]
        profit = row["Profit"]

        if category not in category_data:
            category_data[category] = {
                "total_sales": 0,
                "total_profit": 0,
                "order_count": 0
            }

        category_data[category]["total_sales"] += sales  
        category_data[category]["total_profit"] += profit
        category_data[category]["order_count"] += 1

    # Calculate average order value
    for category in category_data:
        total_sales = category_data[category]["total_sales"]
        order_count = category_data[category]["order_count"]

        if order_count > 0:
            category_data[category]["avg_order_value"] = total_sales / order_count
        else:
            category_data[category]["avg_order_value"] = 0

    return category_data

# %%
def print_regional_performance(region_metrics):
    print("REGIONAL PERFORMANCE")
    print("====================")
    for region, metrics in region_metrics.items():
        print(
            f"{region:<8} "
            f"${metrics['total_sales']:,.2f} | "
            f"Profit: ${metrics['total_profit']:,.2f} | "
            f"Orders: {metrics['order_count']:<4} | "
            f"Avg: ${metrics['avg_order_value']:,.2f}"
        )


def print_category_report(category_metrics):
    print("CATEGORY PERFORMANCE")
    print("====================")
    for category, metrics in category_metrics.items():
        print(category)
        print("-" * len(category))
        print(f"  Total Sales: ${metrics['total_sales']:,.2f}")
        print(f"  Total Profit: ${metrics['total_profit']:,.2f}")
        print(f"  Orders: {metrics['order_count']}")
        print(f"  Avg Order Value: ${metrics['avg_order_value']:,.2f}")
        print()

# %%
metrics = calculate_revenue_metrics(data)
print("REVENUE METRICS")
print("===============")
for key, value in metrics.items():
    if "Profit Margin" in key:
        print(f"{key}: {value:.2f}%")
    elif "Quantity" in key:
        print(f"{key}: {int(value)}")
    else:
        print(f"{key}: ${value:,.2f}")
print()

region_metrics = analyze_by_region(data)
print_regional_performance(region_metrics)
print()

category_metrics = analyze_by_category(data)
print_category_report(category_metrics)

# %% [markdown]
# ### Part 3: Product Analysis

# %%
def find_top_products(sales_data, n=10, metric="Sales"):
    """
    Aggregates data by Product Name and returns top N products by metric.
    metric can be: 'Sales', 'Profit', 'Quantity'
    Returns: list of tuples (product_name, metric_value)
    """
    if not sales_data:
        return []

    if metric not in ["Sales", "Profit", "Quantity"]:
        metric = "Sales"

    totals = {}  

    for row in sales_data:
        product = row.get("Product Name", "Unknown")

        # metric value (Quantity might be int already)
        value = row.get(metric, 0)

        if product not in totals:
            totals[product] = 0

        totals[product] += value

    # Convert to list and sort descending by metric value
    product_list = list(totals.items())
    product_list.sort(key=lambda x: x[1], reverse=True)

    return product_list[:n]

# %%
def analyze_discounts(sales_data):
    """
    - Average discount by category
    - Profit margin comparison: discounted vs non-discounted
    Returns a dictionary of insights.
    """
    if not sales_data:
        return {}

    # Average discount by category
    discount_sum = {}    
    discount_count = {} 

    # Discounted vs Non-discounted totals
    disc_sales = disc_profit = 0
    nodisc_sales = nodisc_profit = 0

    for row in sales_data:
        category = row.get("Category", "Unknown")
        discount = row.get("Discount", 0)
        sales = row.get("Sales", 0)
        profit = row.get("Profit", 0)

        # avg discount by category
        if category not in discount_sum:
            discount_sum[category] = 0
            discount_count[category] = 0

        discount_sum[category] += discount
        discount_count[category] += 1

        # profit margin comparison
        if discount > 0:
            disc_sales += sales
            disc_profit += profit
        else:
            nodisc_sales += sales
            nodisc_profit += profit

    avg_discount_by_category = {}
    for cat in discount_sum:
        avg_discount_by_category[cat] = discount_sum[cat] / discount_count[cat]

    # profit margin (%) = profit / sales * 100
    disc_margin = (disc_profit / disc_sales * 100) if disc_sales != 0 else 0
    nodisc_margin = (nodisc_profit / nodisc_sales * 100) if nodisc_sales != 0 else 0

    return {
        "avg_discount_by_category": avg_discount_by_category,
        "discounted": {
            "total_sales": disc_sales,
            "total_profit": disc_profit,
            "profit_margin_pct": disc_margin
        },
        "non_discounted": {
            "total_sales": nodisc_sales,
            "total_profit": nodisc_profit,
            "profit_margin_pct": nodisc_margin
        }
    }

# %%
def identify_loss_makers(sales_data):
    """
    - Finds all rows with negative profit
    - Returns count + total loss amount
    - Top 5 products with most total losses (most negative profit sum)
    """
    if not sales_data:
        return {}

    loss_count = 0
    total_loss = 0 
    product_losses = {}  
    product_loss_counts = {}  # product - number of loss orders

    for row in sales_data:
        profit = row.get("Profit", 0)
        if profit < 0:
            loss_count += 1
            total_loss += profit  # negative number adds up

            product = row.get("Product Name", "Unknown")
            if product not in product_losses:
                product_losses[product] = 0
                product_loss_counts[product] = 0

            product_losses[product] += profit
            product_loss_counts[product] += 1

    # Top 5 products by total loss (most negative  sort ascending)
    loss_list = list(product_losses.items())
    loss_list.sort(key=lambda x: x[1])  # most negative first
    top_5_loss_products = loss_list[:5]

    #top 5 by count of loss orders:
    count_list = list(product_loss_counts.items())
    count_list.sort(key=lambda x: x[1], reverse=True)
    top_5_by_loss_count = count_list[:5]

    return {
        "loss_order_count": loss_count,
        "total_loss_amount": total_loss,  
        "total_loss_abs": abs(total_loss),
        "top_5_products_by_total_loss": top_5_loss_products,
        "top_5_products_by_loss_count": top_5_by_loss_count
    }

# %%
top_sales = find_top_products(data, n=10, metric="Sales")
top_profit = find_top_products(data, n=10, metric="Profit")
top_qty = find_top_products(data, n=10, metric="Quantity")

print("TOP 10 PRODUCTS BY SALES")
for name, val in top_sales:
    print(f"{name}: ${val:,.2f}")

discount_insights = analyze_discounts(data)
print("\nDISCOUNT INSIGHTS")
print(discount_insights)

loss_report = identify_loss_makers(data)
print("\nLOSS MAKERS")
print(loss_report)

# %% [markdown]
# ### Part 4: Report Generation

# %%
def generate_executive_summary(sales_data, output_file):
 
    metrics = calculate_revenue_metrics(sales_data)
    region_metrics = analyze_by_region(sales_data)
    category_metrics = analyze_by_category(sales_data)

    top10_sales = find_top_products(sales_data, n=10, metric="Sales")
    loss_info = identify_loss_makers(sales_data)
    discount_info = analyze_discounts(sales_data)

  
    with open(output_file, "w", encoding="utf-8") as f:
        f.write("EXECUTIVE SUMMARY REPORT\n")
        f.write("========================\n\n")

        # Overall metrics
        f.write("REVENUE METRICS\n")
        f.write("--------------\n")
        for k, v in metrics.items():
            if "Profit Margin" in k:
                f.write(f"{k}: {v:.2f}%\n")
            elif "Quantity" in k:
                f.write(f"{k}: {int(v)}\n")
            else:
                f.write(f"{k}: ${v:,.2f}\n")
        f.write("\n")

        # Regional summary (top 5 by sales)
        f.write("TOP REGIONS BY SALES\n")
        f.write("--------------------\n")
        region_list = list(region_metrics.items())  # (region, dict)
        region_list.sort(key=lambda item: item[1]["total_sales"], reverse=True)
        for region, info in region_list[:5]:
            f.write(f"{region}: Sales=${info['total_sales']:,.2f}, Profit=${info['total_profit']:,.2f}\n")
        f.write("\n")

        # Category summary (top 5 by sales)
        f.write("TOP CATEGORIES BY SALES\n")
        f.write("-----------------------\n")
        cat_list = list(category_metrics.items())
        cat_list.sort(key=lambda item: item[1]["total_sales"], reverse=True)
        for cat, info in cat_list[:5]:
            f.write(f"{cat}: Sales=${info['total_sales']:,.2f}, Profit=${info['total_profit']:,.2f}\n")
        f.write("\n")

        # Top products
        f.write("TOP 10 PRODUCTS BY SALES\n")
        f.write("------------------------\n")
        for name, val in top10_sales:
            f.write(f"{name}: ${val:,.2f}\n")
        f.write("\n")

        # Discount insights (simple)
        f.write("DISCOUNT INSIGHTS\n")
        f.write("-----------------\n")
        if discount_info:
            f.write("Average discount by category:\n")
            for cat, avg_disc in discount_info["avg_discount_by_category"].items():
                f.write(f"  {cat}: {avg_disc:.2f}\n")

            f.write("\nProfit margin comparison:\n")
            f.write(f"  Discounted margin: {discount_info['discounted']['profit_margin_pct']:.2f}%\n")
            f.write(f"  Non-discounted margin: {discount_info['non_discounted']['profit_margin_pct']:.2f}%\n")
        f.write("\n")

        # Loss makers
        f.write("LOSS MAKERS\n")
        f.write("-----------\n")
        if loss_info:
            f.write(f"Orders with negative profit: {loss_info['loss_order_count']}\n")
            f.write(f"Total loss amount: ${abs(loss_info['total_loss_amount']):,.2f}\n")
            f.write("Top 5 products by total loss:\n")
            for prod, loss in loss_info["top_5_products_by_total_loss"]:
                f.write(f"  {prod}: -${abs(loss):,.2f}\n")

 
    return output_file

# %%
def export_regional_summary(regional_data, output_file):
    headers = ["Region", "Total_Sales", "Total_Profit", "Order_Count", "Avg_Order_Value", "Profit_Margin"]

    with open(output_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(headers)

        for region, info in regional_data.items():
            total_sales = info["total_sales"]
            total_profit = info["total_profit"]
            order_count = info["order_count"]
            avg_order_value = info["avg_order_value"]

            # Calculate profit margin here (because it's not in the dict)
            if total_sales != 0:
                profit_margin = (total_profit / total_sales) * 100
            else:
                profit_margin = 0

            writer.writerow([
                region,
                round(total_sales, 2),
                round(total_profit, 2),
                order_count,
                round(avg_order_value, 2),
                round(profit_margin, 2)
            ])

    return output_file

# %%
def export_top_products(sales_data, output_file, n=20):
    # Aggregate by product
    product_totals = {}  
    # product -> {"Category": ..., "Total Sales": ..., "Total Profit": ..., "Units Sold": ...}

    for row in sales_data:
        product = row["Product Name"]
        category = row["Category"]
        sales = row["Sales"]
        profit = row["Profit"]
        qty = row["Quantity"]

        if product not in product_totals:
            product_totals[product] = {
                "Category": category,
                "Total Sales": 0,
                "Total Profit": 0,
                "Units Sold": 0
            }

        product_totals[product]["Total Sales"] += sales
        product_totals[product]["Total Profit"] += profit
        product_totals[product]["Units Sold"] += qty

    # Sort products by total sales (descending)
    product_list = list(product_totals.items())  # (product, info)
    product_list.sort(key=lambda item: item[1]["Total Sales"], reverse=True)

    top_products = product_list[:n]

    headers = ["Product_Name", "Category", "Total_Sales", "Total_Profit", "Units_Sold"]

    with open(output_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(headers)

        for product, info in top_products:
            writer.writerow([
                product,
                info["Category"],
                round(info["Total Sales"], 2),
                round(info["Total Profit"], 2),
                info["Units Sold"]
            ])

    return output_file

# %%
# After you load data:
data = load_sales_data(STORE_DATA_FILE)

generate_executive_summary(data, "executive_summary.txt")

regional = analyze_by_region(data)
export_regional_summary(regional, "regional_performance.csv")

export_top_products(data, "top_products.csv", n=20)
